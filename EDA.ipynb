# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tabular-playground-series-may-2021/sample_submission.csv
# /kaggle/input/tabular-playground-series-may-2021/train.csv
# /kaggle/input/tabular-playground-series-may-2021/test.csv

# %%
source = pd.read_csv("/kaggle/input/tabular-playground-series-may-2021/train.csv")
test = pd.read_csv("/kaggle/input/tabular-playground-series-may-2021/train.csv")
total_len = len(source)
print(total_len)
# Out:
# 100000

# %%
counts = list(source["target"].value_counts(sort=False).values)
classes = list(source["target"].value_counts(sort=False).index.values)
print(counts)
print(classes)
counts1 = list(test["target"].value_counts(sort=False).values)
classes1 = list(test["target"].value_counts(sort=False).index.values)
print(counts1)
print(classes1)
# Out:
# [12593, 21420, 8490, 57497]
# ['Class_4', 'Class_3', 'Class_1', 'Class_2']
# [12593, 21420, 8490, 57497]
# ['Class_4', 'Class_3', 'Class_1', 'Class_2']

# %%
import matplotlib.pyplot as plt
df_counts = source.groupby("target").id.count()
df_counts
# Out:
# target
# Class_1     8490
# Class_2    57497
# Class_3    21420
# Class_4    12593
# Name: id, dtype: int64

# %%
# fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,8))
# sns.barplot(x=counts,y=classes,order=["Class_1","Class_2","Class_3","Class_4"],ax=ax1)
# sns.barplot(x=per_counts,y=classes,order=["Class_1","Class_2","Class_3","Class_4"],ax=ax2)

# %%
import seaborn as sns
per_counts = [round(i*(100/total_len)) for i in counts]
sns.set_style("ticks", {'grid.linestyle': '--'})
sns.barplot(x=counts,y=classes,order=["Class_1","Class_2","Class_3","Class_4"])
#sns.barplot(x=per_counts,y=classes,order=["Class_1","Class_2","Class_3","Class_4"])
# Out:
# <AxesSubplot:>

# %%
temp = source.drop(columns=["id","target"])

# %%
fig, ax = plt.subplots(figsize=(12, 13))
ax.set_title('\n50 Feature columns distribution(-2 to 10+)\n',loc='left')
sns.boxplot(data=temp,orient='h',showfliers=True,fliersize=0.5,linewidth=0.8,ax=ax)
ax.set(xlabel="\nValue Distribution")
#ax.set_xlim(-3,20)
plt.xlim(-2,10)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(12,12))
temp2 = temp[["feature_7","feature_9","feature_14",
              "feature_15","feature_19","feature_24",
             "feature_28","feature_31","feature_34",
             "feature_38","feature_40","feature_48",]]
ax.set_title('\n50 Intersting feature column distribution(-2 to 10+)\n',loc='left')
sns.boxplot(data=temp2,orient='h',showfliers=True,fliersize=0.5,linewidth=0.8,ax=ax)
ax.set(xlabel="\nValue Distribution")
#ax.set_xlim(-3,20)
plt.xlim(-2,10)
plt.show()

# %%
len(temp2["feature_7"].unique())
